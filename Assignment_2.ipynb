# %% [markdown]
# <a href="https://colab.research.google.com/github/githubsaniya924/Hypothesis_Testing/blob/main/Assignment_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Two-Sample Test

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#Loading the Datasets
stud_data = pd.read_csv('StudentStatistics.csv',sep=';')
stud_data.head()
# Out:
#    RespNr   Location   OAA_ObjCourse                OAA_ObjClass  \
# 0     1.0  Rotterdam  Fully Disagree              Fully Disagree
# 1     2.0    Haarlem        Disagree                    Disagree
# 2     3.0     Diemen     Fully agree                 Fully agree
# 3     4.0  Rotterdam  Fully Disagree  Neither disagree nor agree
# 4     5.0    Haarlem        Disagree                       Agree
#
#    OAA_CourseExec               OAA_RelActObj               OAA_RelActExa  \
# 0  Fully Disagree                    Disagree              Fully Disagree
# 1             NaN              Fully Disagree  Neither disagree nor agree
# 2           Agree                 Fully agree                 Fully agree
# 3        Disagree  Neither disagree nor agree  Neither disagree nor agree
# 4  Fully Disagree  Neither disagree nor agree                 Fully agree
#
#     OAA_RelObjExa             OAA_LearProcAct            OAA_LearProcPrep  \
# ...

# %%
data = pd.read_csv('GSS2012a.csv')
# Out:
# <ipython-input-18-3b3bae26c646>:1: DtypeWarning: Columns (11,115,123,187,274,284,287,288,290,291,292,397,585,595,628,632) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv('GSS2012a.csv')

# %%
data.head()
# Out:
#      year    id       mar1 BMITZVAH accntsci   age     sex      life ENGDO  \
# 0  2012.0   1.0    MARRIED      NaN      NaN  22.0    MALE  EXCITING   NaN
# 1  2012.0   6.0   DIVORCED      NaN      NaN  50.0  FEMALE       NaN   NaN
# 2  2012.0   7.0    MARRIED      NaN      NaN  35.0  FEMALE       NaN   NaN
# 3  2012.0   9.0  SEPARATED      NaN      NaN  28.0  FEMALE   ROUTINE   NaN
# 4  2012.0  11.0   DIVORCED      NaN      NaN  55.0    MALE   ROUTINE   NaN
#
#   SCIENTBR  ...          wrksch        wrkslf           wrkstat  \
# 0      NaN  ...  WORK PART-TIME  SOMEONE ELSE  WORKING PARTTIME
# 1      NaN  ...  WORK FULL-TIME  SOMEONE ELSE             OTHER
# 2      NaN  ...             NaN  SOMEONE ELSE     KEEPING HOUSE
# 3      NaN  ...  WORK PART-TIME           NaN     KEEPING HOUSE
# 4      NaN  ...             NaN  SOMEONE ELSE             OTHER
#
#          wrkwayup wwwhr wwwmin          xmarsex  xmovie          xnorcsiz  \
# ...

# %% [markdown]
# Binary Vs Binary - Fisher Exact Test

# %%
#Binary Vs. Binary
#We need to take two Binary variables
#1. Gender
#2. Cappun (captial punishment)

#Here We need to understand the influence of gender on the captital punishment
#Gender - Male/Female
#cappun - Favor/Oppose

#H0 - Gender has no ifluence on capital punishment
#Ha - Gender has influence on Capital punshiment

# %%
data['sex'].value_counts()
# Out:
# sex
# FEMALE    1088
# MALE       886
# Name: count, dtype: int64

# %%
data['cappun'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-20-8e640e110303> in <cell line: 1>()
# ----> 1 data['cappun'].values_count()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#    6300
#    6301     @final
#
# AttributeError: 'Series' object has no attribute 'values_count'
